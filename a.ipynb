# %%
APPID_LIST = [
    3241660,
    2807960,
    730,
    1808500,
    1030300,
    570,
    578080,
    2246340,
    2592160,
    553850,
    3240220,
    1091500,
    1903340,
    2001120,
    1245620,
    1086940,
    1144200,
    3167020,
    3564740,
    227300,
    108600,
    413150,
    1771300,
    3489700,
    1172470,
    1222140,
    1326470,
    990080,
    1551360,
    1623730,
    1145350,
    2183900,
    230410,
    2139460,
    236390,
    440,
    1973530,
    394360,
    3932890,
    526870,
    3513350,
    3405690,
    2622380,
    814380,
    648800,
    3159330,
    3527290,
    2651280,
    294100,
    1222670,
]

# %%
import pandas as pd
df = pd.read_csv('data/steam_top100_assets_3rd_trimmed.csv')
df = df[df['appid'].isin(APPID_LIST)]
df.count()
