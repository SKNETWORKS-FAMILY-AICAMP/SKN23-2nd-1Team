# %%
import pandas as pd    
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('data/template.xlsx')
fig, ax = plt.subplots(figsize=(8, 4))
sns.barplot(
    data=df,
    x=df['구매총액'],
    y=df.index,
    estimator="mean",   # 평균
    errorbar=None,      # 신뢰구간 제거 (깔끔)
    ax=ax,
)

st.pyplot(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 16
#       6 fig, ax = plt.subplots(figsize=(8, 4))
#       7 sns.barplot(
#       8     data=df,
#       9     x=df['구매총액'],
#    (...)     13     ax=ax,
#      14 )
# ---> 16 st.pyplot(fig)
#
# NameError: name 'st' is not defined
# c:\python_workspace\python\second\second_venv\Lib\site-packages\IPython\core\events.py:96: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\python_workspace\python\second\second_venv\Lib\site-packages\IPython\core\events.py:96: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\python_workspace\python\second\second_venv\Lib\site-packages\IPython\core\events.py:96: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\python_workspace\python\second\second_venv\Lib\site-packages\IPython\core\events.py:96: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\python_workspace\python\second\second_venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\python_workspace\python\second\second_venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\python_workspace\python\second\second_venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\python_workspace\python\second\second_venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
